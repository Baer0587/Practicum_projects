# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Александр, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Это снова Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# # Проект: «Анализ исторических данных стартапов для формирования инвестиционной стратегии»

# %% [markdown]
# **Автор:** Александр

# %% [markdown]
# **Финансовая компания, которая предоставляет льготные займы стартапам, хочет войти на инвестиционный рынок с прицелом на покупку, развитие и последующую перепродажу перспективных стартапов.**

# %% [markdown]
# ## Цель проекта
#
# Подготовить датасет и проверить, что данные в нём соответствуют здравому смыслу, а также ответить на вопросы заказчика как о предобработке, так и о значении данных для бизнеса.
#
# **предстоит принять решения:**
#
# по каким столбцам можно объединять данные из разных таблиц;
#
# можно ли доверять данным о сотрудниках стартапов и их образовании;
#
# что значат покупки за 0 или за 1 доллар;
#
# какая цена в зависимости от категории стартапов и количества раундов финансирования перед его покупкой;
#
# как рассчитать и отобразить численные показатели и динамику.

# %% [markdown]
# **Шаг 1. Знакомство с данными:**
#
# загрузка и первичная предобработка
#
# **1.1.**
# Вывод общей информации, исправление названия столбцов
# Загрузите все данные по проекту.
# Проверьте названия столбцов.
# Выведите информацию, которая необходима вам для принятия решений о предобработке, для каждого из датасетов.
#
# **1.2**.
# Смена типов и анализ пропусков
# Обработайте типы данных в столбцах, которые хранят значения даты и времени, если это необходимо.
# Оцените полноту данных — сделайте предварительный вывод, достаточно ли данных для решения задач проекта.
#
# **Шаг 2. Предобработка данных, предварительное исследование**
#
# **2.1.**
# Раунды финансирования по годам
# Задание необходимо выполнить без объединения и дополнительной предобработки на основе датасета company_and_rounds.csv.
# Составьте сводную таблицу по годам, в которой на основании столбца raised_amount для каждого года указан:
# типичный размер средств, выделяемый в рамках одного раунда;
# общее количество раундов финансирования за этот год.
# Оставьте в таблице информацию только для тех лет, для которых есть информация о более чем 50 раундах финансирования.
# На основе получившейся таблицы постройте график, который будет отражать динамику типичного размера средств, которые стартапы получали в рамках одного раунда финансирования.
# На основе полученных данных ответьте на вопросы:
# В каком году типичный размер собранных в рамках одного раунда средств был максимален?
# Какая тенденция по количеству раундов и выделяемых в рамках каждого раунда средств наблюдалась в 2013 году?
#
# **2.2**.
# Люди и их образование
# Заказчик хочет понять, зависит ли полнота сведений о сотрудниках (например, об их образовании) от размера компаний.
# Оцените, насколько информация об образовании сотрудников полна. Используя датасеты people.csv и education.csv, разделите все компании на несколько групп по количеству сотрудников и оцените среднюю долю сотрудников без информации об образовании в каждой из групп. Обоснуйте выбранные границы групп.
# Оцените, возможно ли для выполнения задания присоединить к этим таблицам ещё и таблицу degrees.csv.
#
# **2.3.**
# Объединять или не объединять — вот в чём вопрос
# Некоторые названия столбцов встречаются в датасетах чаще других. В результате предварительной проверки датасетов было выяснено, что столбец company_id подходит для объединения данных.
# Установите, подходит ли для объединения данных столбец network_username, который встречается в нескольких датасетах. Нам необходимо понимать, дублируется ли для разных датасетов информация в столбцах с таким названием, и если да — то насколько часто.
# Оцените, можно ли использовать столбцы с именем network_username для объединения данных.
#
# **2.4.**
# Проблемный датасет и причина возникновения пропусков
# Во время собственного анализа данных у заказчика больше всего вопросов возникло к датасету company_and_rounds.csv. В нём много пропусков как раз в информации о раундах, которая заказчику важна.
# Любым удобным способом приведите данные в вид, который позволит в дальнейшем проводить анализ в разрезе отдельных компаний. Обратите внимание на структуру датасета, порядок и названия столбцов, проанализируйте значения.
# По гипотезе заказчика данные по компаниям из этой таблицы раньше хранились иначе, более удобным для исследования образом.
# Максимальным образом сохраняя данные, сохранив их связность и исключив возможные возникающие при этом ошибки, подготовьте данные так, чтобы удобно было отобрать компании по параметрам и рассчитать показатели из расчёта на одну компанию без промежуточных агрегаций.
#
# **Шаг 3. Исследовательский анализ объединённых таблиц**
#
# **3.1.**
# Объединение данных
# Объедините данные для ответа на вопросы заказчика, которые касаются интересующих его компаний. Заказчика прежде всего интересуют те компании, которые меняли или готовы менять владельцев. Получение инвестиций или финансирования, по мнению заказчика, означает интерес к покупке или продаже компании.
# В качестве основы для объединённой таблицы возьмите данные из обработанного датасета company_and_rounds.csv — выберите только те компании, у которых указаны значения funding_rounds или investment_rounds больше нуля, или те, у которых в колонке status указано acquired. В результирующей таблице должно получиться порядка 40 тысяч компаний.
# Проверьте полноту и корректность получившейся таблицы. Далее работайте только с этими данными.
#
# **3.2.**
# Анализ выбросов
# Заказчика интересует обычный для рассматриваемого периода размер средств, который предоставлялся компаниям.
# По предобработанному столбцу funding_total графическим способом оцените, какой размер общего финансирования для одной компании будет типичным, а какой — выбивающимся.
# В процессе расчёта значений обратите внимание, например, на показатели, возвращаемые методом .describe(), — объясните их. Применимы ли к таким данным обычные способы нахождения типичных значений?
#
# **3.3.**
# Куплены забесплатно?
# Исследуйте компании, которые были проданы за ноль или за один доллар, и при этом известно, что у них был ненулевой общий объём финансирования.
# Рассчитайте аналитически верхнюю и нижнюю границу выбросов для столбца funding_total и укажите, каким процентилям границы соответствуют.
#
# **3.4.**
# Цены стартапов по категориям
# Категории стартапов с типично высокими ценами покупки стартапов и значительным разбросом цен могут быть привлекательными для крупных инвесторов, которые готовы к высоким рискам ради потенциально больших доходов. Среди категорий стартапов выделите категории стартапов, характеризующиеся:
# типично высокими ценами;
# и наибольшим разбросом цен за стартап.
# Объясните, почему решили составить топ именно из такого числа категорий и почему рассчитывали именно так.
#
# **3.5.**
# Сколько раундов продержится стартап перед покупкой
# Необходимо проанализировать столбец funding_rounds. Исследуйте значения столбца. Заказчика интересует типичное значение количества раундов для каждого возможного статуса стартапа.
# Постройте график, который отображает, сколько в среднем раундов финансирования проходило для стартапов из каждой группы. Сделайте выводы.
#
# **Шаг 4. Итоговый вывод и рекомендации**

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте).
# </div>

# %% [markdown]
# ## Описание данных
#
# **Таблица acquisition**
#
# Содержит информацию о покупках одними компаниями других компаний:
#
# id — идентификатор покупки.
#
# acquiring_company_id — идентификатор покупающей компании.
#
# acquired_company_id — идентификатор покупаемой компании.
#
# term_code — варианты расчёта.
#
# price_amount — сумма сделки.
#
# acquired_at — дата сделки.
#
# Таблица company_and_rounds
#
# Содержит информацию о компаниях и раундах финансирования:
#
# company ID — идентификатор компании.
#
# name — название компании.
#
# category code — категория области деятельности компании.
#
# status — статус компании.
#
# founded at — дата инвестирования.
#
# closed at — дата закрытия компании.
#
# domain — официальный сайт компании.
#
# network username — ник компании в сети.
#
# country code — код страны компании.
#
# investment rounds — число инвестиционных раундов.
#
# funding rounds — число раундов финансирования.
#
# funding total — сумма финансирования.
#
# milestones — вехи финансирования.
#
# funding round id — идентификатор этапа финансирования.
#
# company id — идентификатор компании.
#
# funded at — дата финансирования.
#
# funding round type — тип финансирования.
#
# raised amount — сумма финансирования.
#
# pre money valuation — предварительная денежная оценка.
#
# participants — число участников.
#
# is first round — является ли раунд первым.
#
# is last round — является раунд последним.
#
# **Таблица education**
#
# Содержит информацию об образовании сотрудника:
#
# id — идентификатор записи об образовании.
#
# person_id — идентификатор работника.
#
# instituition — название учебного заведения.
#
# graduated_at — дата получения образования.
#
# **Таблица people**
#
# Содержит информацию о сотрудниках:
#
# id — идентификатор сотрудника.
#
# first_name — имя сотрудника.
#
# last_name — фамилия сотрудника.
#
# company_id — идентификатор компании.
#
# network_username — ник в социальных сетях.
#
# **Таблица degrees**
#
# Содержит информацию о типе образования сотрудника:
#
# id — идентификатор записи.
#
# object_id — идентификатор сотрудника.
#
# degree_type — тип образования.
#
# subject — специальность.

# %% [markdown]
# ## Шаг 1. Знакомство с данными: загрузка и первичная предобработка
#
# Названия файлов:
# * acquisition.csv
# * company_and_rounds.csv
# * people.csv
# * education.csv
# * degrees.csv
#
# Опциональные датасеты:
# * fund.csv
# * investment.csv
#
#
# Они находятся в папке datasets, если вы выполняете работу на платформе. В случае, если вы делаете работу локально, доступ к файлам в папке можно получить по адресу `https://code.s3.yandex.net/datasets/` + имя файла.
#
# ### 1.1. Вывод общей информации, исправление названия столбцов
#
# - Загрузите все данные по проекту.
# - Проверьте названия столбцов.
# - Выведите информацию, которая необходима вам для принятия решений о предобработке, для каждого из датасетов.

# %%
# Импорт библиотек: Начнем с импорта необходимых библиотек
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо, необходимые модули выгружены

# %%
# Загрузка данных
acquisition = pd.read_csv('/datasets/acquisition.csv')
company_and_rounds = pd.read_csv('/datasets/company_and_rounds.csv')
people = pd.read_csv('/datasets/people.csv')
education = pd.read_csv('/datasets/education.csv')
degrees = pd.read_csv('/datasets/degrees.csv')

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Для подгрузки данных можно использовать конструкцию `try-except`, она поможет избежать потенциальных ошибок при загрузке данных, связанных, например, с некорректным указанием путей.
#
# Подробнее о конструкции по ссылке:
#
# https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html
#
# Либо же можно использовать стандартную библиотеку os:
#
# https://pythonworld.ru/moduli/modul-os.html
#
#
# Несколько интересных статей кейсы использования конструкции:
#
# https://www.programiz.com/python-programming/exception-handling
#
# https://towardsdatascience.com/do-not-abuse-try-except-in-python-d9b8ee59e23b
#
# https://www.techbeamers.com/use-try-except-python/
#
# Как вариант в try можно указать корректные пути (в нашем случае глобальные) в except - некорректные (локальные). Можно также специфицровать тип ошибки, FileNotFoundError или задать кастомный тип ошибки (FilePathError, например)
#
# Она полезна, если ты работаешь локально, а потом подгружаешь проект на платформу. Конструкция позволит не падать коду и локально, и на сервере ЯП, так как если не сработает один блок с путями, сработает другой.
#
# Ну и вообще, в целом полезно про эту констуркцию знать, она универсальна и может быть использована в разных задачах.

# %%
# проверяем данные с помощью head и info
# Вывод первых пяти строк таблицы для ознакомления с данными
display(acquisition.head()) 

# # Вывод общей информации о таблице
print(acquisition.info())
# Out:
#    id  acquiring_company_id  acquired_company_id term_code  price_amount  \
# 0   1                    11                   10       NaN      20000000
# 1   7                    59                   72      cash      60000000
# 2   8                    24                  132      cash     280000000
# 3   9                    59                  155      cash     100000000
# 4  10                   212                  215      cash      25000000
#
#   acquired_at
# 0  2007-05-30
# 1  2007-07-01
# 2  2007-05-01
# 3  2007-06-01
# 4  2007-07-01
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9407 entries, 0 to 9406
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9407 non-null   int64
#  1   acquiring_company_id  9407 non-null   int64
#  2   acquired_company_id   9407 non-null   int64
#  3   term_code             1831 non-null   object
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Для вывода датафрейм объекта лучше использовать display(), а не print(). Так будет нагляднее

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# В единственной или последней строке ячейки кода Юпитера, метод print() не обязателен, в отличии от тренажера

# %% [markdown]
# ## исправил (display)

# %% [markdown]
# **На основе предоставленных данных о таблице `acquisition`, краткий вывод:**
#
# ### Таблица `acquisition`
#
# 1. **Общее количество записей**: 9407.
# 2. **Столбцы**:
#    - `id`: Идентификатор покупки (тип `int64`, 9407 ненулевых значений).
#    - `acquiring_company_id`: Идентификатор покупающей компании (тип `int64`, 9407 ненулевых значений).
#    - `acquired_company_id`: Идентификатор покупаемой компании (тип `int64`, 9407 ненулевых значений).
#    - `term_code`: Условия сделки (тип `object`, 1831 ненулевое значение, 7576 пропущенных значений).
#    - `price_amount`: Сумма сделки (тип `int64`, 9407 ненулевых значений).
#    - `acquired_at`: Дата сделки (тип `object`, 9378 ненулевых значений, 29 пропущенных значений).
#
# 3. **Типы данных**:
#    - 4 столбца имеют тип `int64`, что указывает на целочисленные значения.
#    - 2 столбца имеют тип `object`, что может указывать на строковые данные или даты.
#
# 4. **Проблемы с данными**:
#    - Столбец `term_code` имеет значительное количество пропущенных значений (7576), что может потребовать дополнительного анализа или обработки.
#    - Столбец `acquired_at` также имеет 29 пропущенных значений, что может повлиять на временные анализы.
#
# ### Рекомендации:
# - Рассмотреть возможность обработки пропущенных значений в столбцах `term_code` и `acquired_at`. Например, можно заполнить пропуски, если это имеет смысл, или удалить строки с пропущенными значениями, если они не критичны для анализа.
# - Привести столбец `acquired_at` к типу `datetime`, чтобы упростить временной анализ.

# %%
display(company_and_rounds.head())

print(company_and_rounds.info())
# Out:
#    company  ID      name category  code     status founded  at closed  at  \
# 0          1.0  Wetpaint            web  operating  2005-10-17        NaN
# 1          1.0  Wetpaint            web  operating  2005-10-17        NaN
# 2          1.0  Wetpaint            web  operating  2005-10-17        NaN
# 3         10.0   Flektor    games_video   acquired         NaN        NaN
# 4        100.0     There    games_video   acquired         NaN        NaN
#
#              domain network  username country  code  investment  rounds  ...  \
# 0  wetpaint-inc.com   BachelrWetpaint           USA                 0.0  ...
# 1  wetpaint-inc.com   BachelrWetpaint           USA                 0.0  ...
# 2  wetpaint-inc.com   BachelrWetpaint           USA                 0.0  ...
# 3       flektor.com               NaN           USA                 0.0  ...
# 4         there.com               NaN           USA                 0.0  ...
#
# ...

# %% [markdown]
# **На основе предоставленных данных о таблице `company_and_rounds`, краткий вывод:**
#
# ### Таблица `company_and_rounds`
#
# 1. **Общее количество записей**: 217774.
# 2. **Столбцы**:
#    - `company_id`: Идентификатор компании (тип `float64`, 217472 ненулевых значений, 302 пропущенных).
#    - `name`: Название компании (тип `object`, 217472 ненулевых значений, 302 пропущенных).
#    - `category_code`: Категория области деятельности компании (тип `object`, 143886 ненулевых значений, 73888 пропущенных).
#    - `status`: Статус компании (тип `object`, 217472 ненулевых значений, 302 пропущенных).
#    - `founded_at`: Дата основания компании (тип `object`, 109956 ненулевых значений, 107818 пропущенных).
#    - `closed_at`: Дата закрытия компании (тип `object`, 3449 ненулевых значений, 214325 пропущенных).
#    - `domain`: Официальный сайт компании (тип `object`, 147159 ненулевых значений, 70615 пропущенных).
#    - `network_username`: Ник компании в сети (тип `object`, 95534 ненулевых значений, 122240 пропущенных).
#    - `country_code`: Код страны компании (тип `object`, 108607 ненулевых значений, 109167 пропущенных).
#    - `investment_rounds`: Число инвестиционных раундов (тип `float64`, 217472 ненулевых значений, 302 пропущенных).
#    - `funding_rounds`: Число раундов финансирования (тип `float64`, 217472 ненулевых значений, 302 пропущенных).
#    - `funding_total`: Сумма финансирования (тип `float64`, 217472 ненулевых значений, 302 пропущенных).
#    - `milestones`: Вехи финансирования (тип `float64`, 217472 ненулевых значений, 302 пропущенных).
#    - `funding_round_id`: Идентификатор этапа финансирования (тип `float64`, 52928 ненулевых значений, 164846 пропущенных).
#    - `funded_at`: Дата финансирования (тип `object`, 52680 ненулевых значений, 164094 пропущенных).
#    - `funding_round_type`: Тип финансирования (тип `object`, 52928 ненулевых значений, 164846 пропущенных).
#    - `raised_amount`: Сумма финансирования (тип `float64`, 52928 ненулевых значений, 164846 пропущенных).
#    - `pre_money_valuation`: Предварительная денежная оценка (тип `float64`, 52928 ненулевых значений, 164846 пропущенных).
#    - `participants`: Число участников (тип `float64`, 52928 ненулевых значений, 164846 пропущенных).
#    - `is_first_round`: Является ли раунд первым (тип `float64`, 52928 ненулевых значений, 164846 пропущенных).
#    - `is_last_round`: Является ли раунд последним (тип `float64`, 52928 ненулевых значений, 164846 пропущенных).
#
# 3. **Типы данных**:
#    - 12 столбцов имеют тип `float64`, что указывает на целочисленные или вещественные значения.
#    - 10 столбцов имеют тип `object`, что может указывать на строковые данные или даты.
#
# 4. **Проблемы с данными**:
#    - Значительное количество пропущенных значений в столбцах, таких как `category_code`, `closed_at`, `domain`, `network_username`, и других. Это может потребовать дополнительного анализа или обработки.
#    - Столбцы с датами (`founded_at`, `closed_at`, `funded_at`) имеют тип `object`, что требует преобразования в тип `datetime` для упрощения анализа.
#
# ### Рекомендации:
# - Рассмотреть возможность обработки пропущенных значений, особенно в столбцах, которые могут быть критичны для анализа.
# - Привести столбцы с датами к типу `datetime`, чтобы упростить временной анализ.
# - Провести анализ по столбцу `category_code`, чтобы понять, какие категории наиболее распространены и как они соотносятся с другими показателями.

# %%
display(people.head())

print(people.info())
# Out:
#        id  first_name    last_name  company_id network_username
# 0      10        Mark   Zuckerberg         5.0              NaN
# 1     100       Peter       Lester        27.0              NaN
# 2    1000  Dr. Steven  E. Saunders       292.0              NaN
# 3   10000        Neil        Capel      2526.0              NaN
# 4  100000         Sue       Pilsch         NaN              NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226709 entries, 0 to 226708
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                226709 non-null  int64
#  1   first_name        226704 non-null  object
#  2   last_name         226708 non-null  object
#  3   company_id        34615 non-null   float64
#  4   network_username  38867 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 8.6+ MB
# None

# %% [markdown]
# **На основе предоставленных данных о таблице `people`, краткий вывод:**
#
# ### Таблица `people`
#
# 1. **Общее количество записей**: 226709.
# 2. **Столбцы**:
#    - `id`: Идентификатор сотрудника (тип `int64`, 226709 ненулевых значений).
#    - `first_name`: Имя сотрудника (тип `object`, 226704 ненулевых значений, 5 пропущенных значений).
#    - `last_name`: Фамилия сотрудника (тип `object`, 226708 ненулевых значений, 1 пропущенное значение).
#    - `company_id`: Идентификатор компании, в которой работает сотрудник (тип `float64`, 34615 ненулевых значений, 192094 пропущенных значений).
#    - `network_username`: Ник сотрудника в социальных сетях (тип `object`, 38867 ненулевых значений, 187842 пропущенных значений).
#
# 3. **Типы данных**:
#    - 1 столбец имеет тип `int64` (идентификатор).
#    - 1 столбец имеет тип `float64` (идентификатор компании).
#    - 3 столбца имеют тип `object` (строковые данные).
#
# 4. **Проблемы с данными**:
#    - Значительное количество пропущенных значений в столбце `company_id` (192094 из 226709), что может указывать на то, что многие сотрудники не привязаны к какой-либо компании.
#    - Также есть пропущенные значения в столбцах `first_name`, `last_name` и `network_username`, хотя их количество относительно невелико.
#
# ### Рекомендации:
# - Рассмотреть возможность обработки пропущенных значений в столбце `company_id`, чтобы понять, как это может повлиять на анализ. Возможно, стоит проверить, есть ли сотрудники без привязки к компании, и выяснить причины.
# - Если `network_username` важен для анализа, подумать о том, как обработать пропуски в этом столбце.
# - Провести анализ по именам и фамилиям, чтобы выявить возможные дубликаты или аномалии.

# %%
display(education.head())

print(education.info())
# Out:
#    id  person_id                      instituition graduated_at
# 0   1       6117                               NaN          NaN
# 1   2       6136  Washington University, St. Louis   1990-01-01
# 2   3       6136                 Boston University   1992-01-01
# 3   4       6005           University of Greenwich   2006-01-01
# 4   5       5832                   Rice University          NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109610 entries, 0 to 109609
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            109610 non-null  int64
#  1   person_id     109610 non-null  int64
#  2   instituition  109555 non-null  object
#  3   graduated_at  58054 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 3.3+ MB
# None

# %% [markdown]
# **На основе предоставленных данных о таблице `education`, краткий вывод:**
#
# ### Таблица `education`
#
# 1. **Общее количество записей**: 109610.
# 2. **Столбцы**:
#    - `id`: Идентификатор записи об образовании (тип `int64`, 109610 ненулевых значений).
#    - `person_id`: Идентификатор человека, к которому относится запись (тип `int64`, 109610 ненулевых значений).
#    - `instituition`: Название учебного заведения (тип `object`, 109555 ненулевых значений, 55 пропущенных значений).
#    - `graduated_at`: Дата окончания учебного заведения (тип `object`, 58054 ненулевых значений, 51556 пропущенных значений).
#
# 3. **Типы данных**:
#    - 2 столбца имеют тип `int64` (идентификаторы).
#    - 2 столбца имеют тип `object` (строковые данные).
#
# 4. **Проблемы с данными**:
#    - Столбец `instituition` имеет небольшое количество пропущенных значений (55), что может быть не критично.
#    - Столбец `graduated_at` имеет значительное количество пропущенных значений (51556), что может затруднить анализ временных аспектов образования.
#
# ### Рекомендации:
# - Рассмотреть возможность обработки пропущенных значений в столбце `graduated_at`, чтобы понять, как это может повлиять на анализ. Возможно, стоит выяснить, почему отсутствуют даты окончания.
# - Привести столбец `graduated_at` к типу `datetime`, чтобы упростить временной анализ.
# - Провести анализ по учебным заведениям, чтобы выявить наиболее распространенные и их связь с другими показателями.

# %%
display(degrees.head())

print(degrees.info())
# Out:
#    id object_id degree_type                       subject
# 0   1    p:6117         MBA                           NaN
# 1   2    p:6136          BA               English, French
# 2   3    p:6136          MS            Mass Communication
# 3   4    p:6005          MS           Internet Technology
# 4   5    p:5832         BCS  Computer Science, Psychology
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109610 entries, 0 to 109609
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           109610 non-null  int64
#  1   object_id    109610 non-null  object
#  2   degree_type  98392 non-null   object
#  3   subject      81298 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 3.3+ MB
# None

# %% [markdown]
# **На основе предоставленных данных о таблице `degrees`, вот краткий вывод:**
#
# ### Таблица `degrees`
#
# 1. **Общее количество записей**: 109610.
# 2. **Столбцы**:
#    - `id`: Идентификатор записи о степени (тип `int64`, 109610 ненулевых значений).
#    - `object_id`: Идентификатор объекта (тип `object`, 109610 ненулевых значений).
#    - `degree_type`: Тип степени (тип `object`, 98392 ненулевых значений, 11218 пропущенных значений).
#    - `subject`: Предметы, по которым получена степень (тип `object`, 81298 ненулевых значений, 28312 пропущенных значений).
#
# 3. **Типы данных**:
#    - 1 столбец имеет тип `int64` (идентификатор).
#    - 3 столбца имеют тип `object` (строковые данные).
#
# 4. **Проблемы с данными**:
#    - Значительное количество пропущенных значений в столбцах `degree_type` (11218) и `subject` (28312). Это может затруднить анализ типов степеней и их предметов.
#
# ### Рекомендации:
# - Рассмотреть возможность обработки пропущенных значений в столбцах `degree_type` и `subject`. Это может включать заполнение пропусков, если это имеет смысл, или удаление строк с пропущенными значениями в зависимости от контекста.

# %% [markdown]
# ## Вывод
#
# **1. Таблица acquisition (покупки компаний)**
#  **Записей:** 9,407
#
#  **Столбцы:**
#
# id, acquiring_company_id, acquired_company_id, price_amount - без пропусков
#
# term_code - только 1,831 непустых значений (19.5%)
#
# acquired_at - 29 пропусков (0.3%)
#
# **2. Таблица company_and_rounds (компании и финансирование)**
#
#  **Записей:** 217,774
#
#  **Проблемы:**
#   Много пропусков в столбцах:
#   founded_at - 49.5% пропусков
#   closed_at- 98.4% пропусков
#   Данные о раундах финансирования (funding_round_id и др.) - 75.7% пропусков
#
# **3. Таблица people (сотрудники)**
#
#  **Записей:** 226,709
#
#  **Ключевые моменты:**
#    company_id - только 34,615 значений (15.3%)
#    network_username - 17.1% заполнено
#
# **4. Таблица education (образование)**
#
#  **Записей:** 109,610
#  **Заполненность:**
#
#    gaduated_at - 53% пропусков
#    instituition - 55 пропусков
#
# **5. Таблица degrees (типы образования)**
#
#  **Записей:** 109,610
#  **Заполненность:**
#
#    degree_type - 10.2% пропусков
#    subject - 25.8% пропусков
#
# **6.  Соответствие описанию:** Данные в целом соответствуют описанию, но есть несоответствия:
#
# В таблице company_and_rounds названия столбцов пишутся через **пробелы** (например "company ID" вместо "company_ID"), **нажно заминить пробелы на подчеркивания к единому стилю!**

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# На этом этапе всё хорошо. Ты корректно выгрузил данные и посмотрел их содержимое.  Можно приступать к следующему шагу
# </div>

# %% [markdown]
# ### 1.2. Смена типов и анализ пропусков
#
# - Обработайте типы данных в столбцах, которые хранят значения даты и времени, если это необходимо.
# - Оцените полноту данных — сделайте предварительный вывод, достаточно ли данных для решения задач проекта.

# %% [markdown]
# **Преобразовать названия столбцов всех таблиц в формат (snake_case), использовать метод (str.replace) и (str.lower)**

# %%
# Функция для преобразования названий столбцов в snake_case
def to_snake_case(column_name):
    # Заменяем пробелы на подчеркивания и преобразуем в нижний регистр
    snake_case_name = '_'.join(column_name.strip().lower().split())
    # Убираем двойные подчеркивания
    return snake_case_name.replace('__', '_')

# Применение функции к названиям столбцов всех таблиц
acquisition.columns = [to_snake_case(col) for col in acquisition.columns]
company_and_rounds.columns = [to_snake_case(col) for col in company_and_rounds.columns]
people.columns = [to_snake_case(col) for col in people.columns]
education.columns = [to_snake_case(col) for col in education.columns]
degrees.columns = [to_snake_case(col) for col in degrees.columns]

# Проверка новых названий столбцов
print(acquisition.columns)
# Out:
# Index(['id', 'acquiring_company_id', 'acquired_company_id', 'term_code',
#        'price_amount', 'acquired_at'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
#
# * также интересным является подход с использованием list comprehensions:
#
# `df.columns = [x.lower().replace(' ', '_') for x in df.columns.values]`
#
#
# Данный подход использует list comprehensions, что может быть быстрее на больших датасетах благодаря оптимизации Python для list comprehensions. Этот метод также предоставляет гибкость в добавлении дополнительных операций или условий при необходимости. Однако, он может быть менее очевидным для тех, кто только начинает работать с Python. Этот подход "интересен" тем, что он показывает, как одна и та же задача может быть решена разными способами, и некоторые из них могут быть более эффективными или гибкими в зависимости от конкретного контекста.

# %% [markdown]
# **Итог** названия пишутся через подчеркивания

# %%
print(company_and_rounds.columns)
# Out:
# Index(['company_id', 'name', 'category_code', 'status', 'founded_at',
#        'closed_at', 'domain', 'network_username', 'country_code',
#        'investment_rounds', 'funding_rounds', 'funding_total', 'milestones',
#        'funding_round_id', 'company_id', 'funded_at', 'funding_round_type',
#        'raised_amount', 'pre_money_valuation', 'participants',
#        'is_first_round', 'is_last_round'],
#       dtype='object')

# %% [markdown]
# **Итог** названия пишутся через подчеркивания + видно дублекаты company_id !!

# %%
print(people.columns)
# Out:
# Index(['id', 'first_name', 'last_name', 'company_id', 'network_username'], dtype='object')

# %% [markdown]
# **Итог** названия пишутся через подчеркивания

# %%
print(education.columns)
# Out:
# Index(['id', 'person_id', 'instituition', 'graduated_at'], dtype='object')

# %% [markdown]
# **Итог** названия пишутся через подчеркивания

# %%
print(degrees.columns)
# Out:
# Index(['id', 'object_id', 'degree_type', 'subject'], dtype='object')

# %% [markdown]
# **Итог** названия в таблицах пишутся через нижнее подчеркивание и в таблице **company_and_rounds** пресутсвует дубликат  **company_id**

# %% [markdown]
# **Обработка типы данных в таблицах и привести столбцы, содержащие даты и время, к типу (datetime),
# использовать метод (pd.to_datetime())**

# %%
# Приведение типов данных в таблице acquisition
acquisition['acquired_at'] = pd.to_datetime(acquisition['acquired_at'], errors='coerce')

# Приведение типов данных в таблице company_and_rounds
company_and_rounds['founded_at'] = pd.to_datetime(company_and_rounds['founded_at'], errors='coerce')
company_and_rounds['closed_at'] = pd.to_datetime(company_and_rounds['closed_at'], errors='coerce')
company_and_rounds['funded_at'] = pd.to_datetime(company_and_rounds['funded_at'], errors='coerce')

# Приведение типов данных в таблице education
education['graduated_at'] = pd.to_datetime(education['graduated_at'], errors='coerce')

# %%
# Проверка результатов
print(acquisition.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9407 entries, 0 to 9406
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9407 non-null   int64
#  1   acquiring_company_id  9407 non-null   int64
#  2   acquired_company_id   9407 non-null   int64
#  3   term_code             1831 non-null   object
#  4   price_amount          9407 non-null   int64
#  5   acquired_at           9378 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 441.1+ KB
# None

# %% [markdown]
# **итог** Столбец (acquired_at) был успешно преобразован в тип (datetime64[ns])

# %%
# Проверка результатов
print(company_and_rounds.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217774 entries, 0 to 217773
# Data columns (total 22 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   company_id           217472 non-null  float64
#  1   name                 217472 non-null  object
#  2   category_code        143886 non-null  object
#  3   status               217472 non-null  object
#  4   founded_at           109956 non-null  datetime64[ns]
#  5   closed_at            3449 non-null    datetime64[ns]
#  6   domain               147159 non-null  object
#  7   network_username     95534 non-null   object
#  8   country_code         108607 non-null  object
#  9   investment_rounds    217472 non-null  float64
#  10  funding_rounds       217472 non-null  float64
#  11  funding_total        217472 non-null  float64
#  12  milestones           217472 non-null  float64
#  13  funding_round_id     52928 non-null   float64
# ...

# %% [markdown]
# **итог** Столбец (founded_at и closed_at ) был успешно преобразован в тип (datetime64[ns])

# %%
# Проверка результатов
print(education.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109610 entries, 0 to 109609
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            109610 non-null  int64
#  1   person_id     109610 non-null  int64
#  2   instituition  109555 non-null  object
#  3   graduated_at  58054 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 3.3+ MB
# None

# %% [markdown]
# **итог** Столбец (graduated_at) был успешно преобразован в тип (datetime64[ns])

# %% [markdown]
# **Проверка дубликатов**

# %%
print("Дубликаты столбцов:", company_and_rounds.columns[company_and_rounds.columns.duplicated()].tolist())
# Out:
# Дубликаты столбцов: ['company_id']

# %%
# Удалим дубликат (второе вхождение)
company_and_rounds = company_and_rounds.loc[:, ~company_and_rounds.columns.duplicated()]
print("Обновлённые названия столбцов:", company_and_rounds.columns.tolist())
# Out:
# Обновлённые названия столбцов: ['company_id', 'name', 'category_code', 'status', 'founded_at', 'closed_at', 'domain', 'network_username', 'country_code', 'investment_rounds', 'funding_rounds', 'funding_total', 'milestones', 'funding_round_id', 'funded_at', 'funding_round_type', 'raised_amount', 'pre_money_valuation', 'participants', 'is_first_round', 'is_last_round']

# %%
# Проверка пропусков
print (acquisition.isnull().sum())
# Out:
# id                         0
# acquiring_company_id       0
# acquired_company_id        0
# term_code               7576
# price_amount               0
# acquired_at               29
# dtype: int64

# %% [markdown]
# **В результате проверки пропусков в данных видно, что:**
# Столбец `term_code` содержит 7576 пропусков.
# Столбец `acquired_at` содержит 29 пропусков.
# Остальные столбцы (`id`, `acquiring_company_id`, `acquired_company_id`, `price_amount`) не содержат пропусков.

# %%
# Проверка пропусков
print (company_and_rounds.isnull().sum())
# Out:
# company_id                302
# name                      302
# category_code           73888
# status                    302
# founded_at             107818
# closed_at              214325
# domain                  70615
# network_username       122240
# country_code           109167
# investment_rounds         302
# funding_rounds            302
# funding_total             302
# milestones                302
# funding_round_id       164846
# funded_at              165094
# funding_round_type     164846
# raised_amount          164846
# pre_money_valuation    164846
# participants           164846
# is_first_round         164846
# is_last_round          164846
# dtype: int64

# %% [markdown]
# **В результате проверки пропусков в данных `company_and_rounds` видно, что:**
#
# Столбцы `company_id`, `name`, `status`, `investment_rounds`, `funding_rounds`, `funding_total`, и `milestones` имеют по 302 пропуска.
# Столбец `category_code` содержит 73,888 пропусков.
# Столбец `founded_at` содержит 107,818 пропусков.
# Столбец `closed_at` содержит 214,325 пропусков.
# Столбец `domain` содержит 70,615 пропусков.
# Столбец `network_username` содержит 122,240 пропусков.
# Столбец `country_code` содержит 109,167 пропусков.
# Столбцы `funding_round_id`, `funded_at`, `funding_round_type`, `raised_amount`, `pre_money_valuation`, `participants`, `is_first_round`, и `is_last_round` содержат по 164,846 пропусков.
#
# **Краткий вывод:** Данные содержат значительное количество пропусков в различных столбцах, особенно в `closed_at`, `founded_at`, и связанных с инвестиционными раундами.

# %%
# Проверка пропусков
print (people.isnull().sum())
# Out:
# id                       0
# first_name               5
# last_name                1
# company_id          192094
# network_username    187842
# dtype: int64

# %% [markdown]
# **В результате проверки пропусков в данных `people` видно, что:**
#
# Столбец `first_name` содержит 5 пропусков.
# Столбец `last_name` содержит 1 пропуск.
# Столбец `company_id` содержит 192,094 пропусков.
# Столбец `network_username` содержит 187,842 пропусков.
# Столбец `id` не содержит пропусков.
#
# **Краткий вывод:** Данные имеют значительное количество пропусков в столбцах `company_id` и `network_username`, что может указывать на отсутствие информации о компании или сетевом имени для многих записей. Пропуски в именах (`first_name` и `last_name`) минимальны.

# %%
# Проверка пропусков
print (education.isnull().sum())
# Out:
# id                  0
# person_id           0
# instituition       55
# graduated_at    51556
# dtype: int64

# %% [markdown]
# **В результате проверки пропусков в данных `education` видно, что:**
#
# Столбцы `id` и `person_id` не содержат пропусков.
# Столбец `instituition` содержит 55 пропусков.
# Столбец `graduated_at` содержит 51,556 пропусков.
#
# **Краткий вывод:** Пропуски в столбце `instituition` минимальны, но значительное количество пропусков в `graduated_at` может указывать на отсутствие информации о дате окончания обучения для многих записей.

# %%
# Проверка пропусков
print (degrees.isnull().sum())
# Out:
# id                 0
# object_id          0
# degree_type    11218
# subject        28312
# dtype: int64

# %% [markdown]
# **В результате проверки пропусков в данных `degrees` видно, что:**
#
# Столбцы `id` и `object_id` не содержат пропусков.
# Столбец `degree_type` содержит 11,218 пропусков.
# Столбец `subject` содержит 28,312 пропусков.
#
# **Краткий вывод:** Данные содержат значительное количество пропусков в столбцах `degree_type` и `subject`

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Да, типы данных верно заменены.
#
# Даты - это основной источник проблем с типами данных. Иногда приходится менять и другие типы, то даты почти всегда будут в неподходящем формате при выгрузке из БД.

# %% [markdown]
# ## Шаг 2. Предобработка данных, предварительное исследование

# %% [markdown]
# ### 2.1. Раунды финансирования по годам
#
# Задание необходимо выполнить без объединения и дополнительной предобработки на основе датасета `company_and_rounds.csv`.
#
# - Составьте сводную таблицу по годам, в которой на основании столбца `raised_amount` для каждого года указан:
#     - типичный размер средств, выделяемый в рамках одного раунда;
#     - общее количество раундов финансирования за этот год.
#
# - Оставьте в таблице информацию только для тех лет, для которых есть информация о более чем 50 раундах финансирования.
# - На основе получившейся таблицы постройте график, который будет отражать динамику типичного размера средств, которые стартапы получали в рамках одного раунда финансирования.
#
# На основе полученных данных ответьте на вопросы:
#
# - В каком году типичный размер собранных в рамках одного раунда средств был максимален?
# - Какая тенденция по количеству раундов и выделяемых в рамках каждого раунда средств наблюдалась в 2013 году?

# %%
# 1. Создаем столбец year из funded_at (с обработкой ошибок)
company_and_rounds['year'] = pd.to_datetime(company_and_rounds['funded_at'], errors='coerce').dt.year

# 2. Создаем сводную таблицу
summary = company_and_rounds.groupby('year').agg(
    Типичный_размер_раунда=('raised_amount', 'median'),
    Количество_раундов=('raised_amount', 'count')
).reset_index()

# 3. Фильтрация (только года с >50 раундами)
summary = summary[summary['Количество_раундов'] > 50]

# 4. Добавление скользящей средней
summary['Скользящая_средняя'] = summary['Типичный_размер_раунда'].rolling(window=3, min_periods=1).mean()

# 5. Корректировка на инфляцию (примерные коэффициенты дефляции)
deflation_factors = {
    2000: 1.5, 2001: 1.45, 2002: 1.4, 2003: 1.35, 2004: 1.3,
    2005: 1.25, 2006: 1.2, 2007: 1.15, 2008: 1.1, 2009: 1.05,
    2010: 1.0, 2011: 0.95, 2012: 0.9, 2013: 0.85
}

summary['Корректированный_размер'] = summary.apply(
    lambda row: row['Типичный_размер_раунда'] * deflation_factors.get(row['year'], 1), axis=1
)

# 6. Построение графика
plt.figure(figsize=(12, 6))
plt.plot(summary['year'], summary['Типичный_размер_раунда']/1e6, 
         marker='o', linestyle='-', linewidth=2, label='Медианный размер раунда')
plt.plot(summary['year'], summary['Скользящая_средняя']/1e6, 
         marker='o', linestyle='--', linewidth=2, label='Скользящая средняя')
plt.plot(summary['year'], summary['Корректированный_размер']/1e6, 
         marker='o', linestyle=':', linewidth=2, label='Корректированный размер')
plt.title('Динамика финансирования стартапов по годам', fontsize=14)
plt.xlabel('Год')
plt.ylabel('Размер раунда (млн USD)')
plt.grid(True)
plt.legend()

# 7. Вывод таблицы
print("Сводная таблица финансирования по годам:")
display(summary.rename(columns={
    'year': 'Год',
    'Типичный_размер_раунда': 'Типичный размер раунда (USD)',
    'Количество_раундов': 'Кол-во раундов',
    'Скользящая_средняя': 'Скользящая средняя (USD)',
    'Корректированный_размер': 'Корректированный размер (USD)'
}))

plt.show()
# Out:
# Сводная таблица финансирования по годам:
#        Год  Типичный размер раунда (USD)  Кол-во раундов  \
# 15  1999.0                     2000000.0              76
# 16  2000.0                     4200000.0             125
# 17  2001.0                     3000000.0              96
# 18  2002.0                     4200000.0             116
# 19  2003.0                     3000000.0             159
# 20  2004.0                     5000000.0             291
# 21  2005.0                     5500000.0            1633
# 22  2006.0                     5000000.0            2436
# 23  2007.0                     3973320.0            3279
# 24  2008.0                     3110000.0            3774
# 25  2009.0                     2000000.0            4151
# 26  2010.0                     1602500.0            6221
# 27  2011.0                     1200000.0            9204
# 28  2012.0                     1000000.0            9970
# 29  2013.0                     1200000.0           11072
#
# ...

# %% [markdown]
# **Анализ данных о финансировании стартапов
# На основе предоставленных данных можно сделать следующие выводы:**
#
# Год с максимальным типичным размером раунда:
#
# Максимальный медианный размер финансирования составлял 5,500,000 USD
#
# Этот показатель был достигнут в 2005 году
#
# **Ключевые наблюдения:**
#
# Пиковое значение пришлось на 2005 год, несмотря на то, что:
#
# Количество раундов в этом году (1,633) было существенно меньше, чем в последующие годы
#
# В 2004 году размер раунда был лишь немного меньше (5,000,000 USD)
#
# После 2005 года наблюдается устойчивая негативная динамика:
#
# Постепенное снижение медианного размера раунда
#
# Особенно резкое падение после 2008 года (финансовый кризис)
#
# К 2013 году размер сократился до 1,200,000 USD (в 4.6 раз меньше пикового значения)

# %% [markdown]
# ***Анализ тенденций в 2013 году
# На основе предоставленных данных можно выделить следующие ключевые тенденции:**
#
# **1. По количеству раундов:**
# 11,072 раунда — абсолютный максимум за весь период (1999–2013)
#
# Рост на 11% по сравнению с 2012 годом (9,970 раундов)
#
# Устойчивый ежегодный рост количества раундов с 2009 года:
#
# 2009: 4,151
#
# 2010: 6,221 (+49%)
#
# 2011: 9,204 (+48%)
#
# 2012: 9,970 (+8%)
#
# 2013: 11,072 (+11%)
#
# **2. По размеру финансирования:**
# Медианный размер раунда: 1,200,000 USD
#
# Снижение на 20% по сравнению с 2012 годом (1,500,000 USD)
#
# Общая негативная динамика с 2005 года:
#
# 2005: 5,500,000 USD (пик)
#
# 2013: 1,200,000 USD (падение в 4.6 раз)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
#
# - Верно что использована медиана
#
#
# - График получен верный.  Оформление отличное - надписи по осям, заголовок на месте
#
#
#
#
#
# <div class="alert alert-warning">
#
# Совет 🤔:
#
#
#
#
#
# - Когда имеем дело с временными рядами, есть такой классический инструмент как скользящая средняя. Тенденции очевидны и так, но если хочешь можешь наложить, для сглаживания
#
#
#
# - Кстати тут можно добавить коэффициент дефляции,  ведь покупательная способность одного доллара в 2000 и 2013 года разная. Такой вот экономический аспектик

# %% [markdown]
# ### 2.2. Люди и их образование
#
# Заказчик хочет понять, зависит ли полнота сведений о сотрудниках (например, об их образовании) от размера компаний.
#
# - Оцените, насколько информация об образовании сотрудников полна. Используя датасеты `people.csv` и `education.csv`, разделите все компании на несколько групп по количеству сотрудников и оцените среднюю долю сотрудников без информации об образовании в каждой из групп. Обоснуйте выбранные границы групп.
# - Оцените, возможно ли для выполнения задания присоединить к этим таблицам ещё и таблицу `degrees.csv`.

# %%
# Подсчет количества сотрудников в каждой компании
company_counts = people['company_id'].value_counts().reset_index()
company_counts.columns = ['company_id', 'employee_count']

# Определение границ групп
bins = [0, 10, 50, 200, 500, float('inf')]
labels = ['1-10', '11-50', '51-200', '201-500', '500+']
company_counts['group'] = pd.cut(company_counts['employee_count'], bins=bins, labels=labels, right=False)

# Объединение с таблицей education для получения информации об образовании
merged = pd.merge(people, education, left_on='id', right_on='person_id', how='left')

# Добавление группы в объединенную таблицу
merged = pd.merge(merged, company_counts[['company_id', 'group']], on='company_id')

# Расчет доли сотрудников без информации об образовании
missing_education = merged['instituition'].isnull().groupby(merged['group']).mean()

# Вывод результатов
print(missing_education)
# Out:
# group
# 1-10       0.369581
# 11-50      0.314941
# 51-200     0.196487
# 201-500    0.202128
# 500+            NaN
# Name: instituition, dtype: float64

# %% [markdown]
# ### Результаты
#
# - **1-10 сотрудников**: 36.96% сотрудников не имеют информации об образовании.
# - **11-50 сотрудников**: 31.49% сотрудников не имеют информации об образовании.
# - **51-200 сотрудников**: 19.65% сотрудников не имеют информации об образовании.
# - **201-500 сотрудников**: 20.21% сотрудников не имеют информации об образовании.
# - **500+ сотрудников**: Данные отсутствуют (NaN), что может означать, что в вашем наборе данных нет компаний с более чем 500 сотрудниками.
#
# ### Интерпретация результатов
#
# 1. **Тенденция**: С увеличением размера компании (по количеству сотрудников) доля сотрудников без информации об образовании, как правило, снижается. Это может указывать на то, что крупные компании более тщательно собирают данные о своих сотрудниках, включая информацию об образовании.
#
# 2. **Группа 500+**: Отсутствие данных для группы компаний с более чем 500 сотрудниками может быть связано с тем, что в вашем наборе данных нет таких компаний. Это может ограничивать возможность анализа для очень крупных компаний.
#
# ### Обоснование границ групп
#
# Границы групп были выбраны на основе типичных размеров компаний:
# - **1-10 сотрудников**: очень маленькие компании или стартапы.
# - **11-50 сотрудников**: малые компании.
# - **51-200 сотрудников**: средние компании.
# - **201-500 сотрудников**: крупные компании.
# - **500+ сотрудников**: очень крупные компании.
#
# Эти группы позволяют увидеть, как полнота информации об образовании варьируется в зависимости от размера компании.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отлично, что используешь `pd.cut()` для разделения на группы. Это довольно удобный вариант разделения👍👍👍
# </div>

# %% [markdown]
# ### 2.3. Объединять или не объединять — вот в чём вопрос
#
# Некоторые названия столбцов встречаются в датасетах чаще других. В результате предварительной проверки датасетов было выяснено, что столбец `company_id` подходит для объединения данных.
#
# - Установите, подходит ли для объединения данных столбец `network_username`, который встречается в нескольких датасетах. Нам необходимо понимать, дублируется ли для разных датасетов информация в столбцах с таким названием, и если да — то насколько часто.
# - Оцените, можно ли использовать столбцы с именем `network_username` для объединения данных.

# %%
datasets = {
    'people': people,
    'company_and_rounds': company_and_rounds,
    'education': education,
    'degrees': degrees
}

# Проверяем наличие столбца в каждом датасете
for name, df in datasets.items():
    if 'network_username' in df.columns:
        print(f"{name}: содержит столбец network_username ({len(df)} записей)")
    else:
        print(f"{name}: не содержит столбец network_username")
# Out:
# people: содержит столбец network_username (226709 записей)
# company_and_rounds: содержит столбец network_username (217774 записей)
# education: не содержит столбец network_username
# degrees: не содержит столбец network_username

# %% [markdown]
# **Столбец network_username** НЕ ПРИГОДЕН для объединения данных по следующим причинам:
#
# Недоступность в других таблицах: Невозможно использовать для join/merge

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
#
#
# 👍Кажется результат логичный

# %% [markdown]
# ### 2.4. Проблемный датасет и причина возникновения пропусков
#
# Во время собственного анализа данных у заказчика больше всего вопросов возникло к датасету `company_and_rounds.csv`. В нём много пропусков как раз в информации о раундах, которая заказчику важна.
#
# - Любым удобным способом приведите данные в вид, который позволит в дальнейшем проводить анализ в разрезе отдельных компаний. Обратите внимание на структуру датасета, порядок и названия столбцов, проанализируйте значения.
#
# По гипотезе заказчика данные по компаниям из этой таблицы раньше хранились иначе, более удобным для исследования образом.
#
# - Максимальным образом сохраняя данные, сохранив их связность и исключив возможные возникающие при этом ошибки, подготовьте данные так, чтобы удобно было отобрать компании по параметрам и рассчитать показатели из расчёта на одну компанию без промежуточных агрегаций.

# %%
# Проверка структуры
print(f"Строк: {len(df)}, Столбцов: {len(df.columns)}")
print("\nТипы данных:\n", df.dtypes)
print("\nПроцент пропусков:\n", df.isnull().mean().sort_values(ascending=False).round(2))
# Out:
# Строк: 109610, Столбцов: 4
#
# Типы данных:
#  id              int64
# object_id      object
# degree_type    object
# subject        object
# dtype: object
#
# Процент пропусков:
#  subject        0.26
# degree_type    0.10
# id             0.00
# object_id      0.00
# dtype: float64

# %% [markdown]
# ## **ПОДСКАЖИТЕ пожалйста я запутался далее ((( проверьте напишите коментарии по исправлению и дальнейшим действиям подробнне по конкретнее напишите коменты  все таки я новичок пожалуйста !!**

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Давай здесь немного подробнее этот раздел разберем. Смотри, у нас фактически "склеены" две таблицы - данные по компаниям, данные по раундам финансирования.
#
# Допустим, для анализа нам нужны только данные для компании. Нам бы хотелось иметь таблицу только с этими данными, без информации о раундах. Давай выделим отдельно эту таблицу. А если точнее, то лучше всего разделить нашу таблицу на две, которые и были изначально -про компании отдельно столбцы взять, про финанасирования столбцы в отдельную таблицу скопировать.
#
# После этого интересующую нас таблицу с компаниями можно обработать: дубликаты, пропуски, оптимизировать типы данных.
#
#
# </div>

# %% [raw]
# #КОД РЕВЬЮЕРА
# #Делаем отдельную таблицу по компаниям
# df_company = df_company_and_rounds[['company_id_found', 'name', 'category_code', 'status',
#                              'founded_at', 'closed_at', 'domain',
#                              'network_username', 'country_code',
#                              'investment_rounds', 'funding_rounds',
#                             'funding_total', 'milestones']]
# #Убираем дубли записей
# df_company=df_company_and_rounds.drop_duplicates(subset=['company_id_found', 'name', 'category_code', 'status',
#                              'founded_at', 'closed_at', 'domain',
#                              'network_username', 'country_code', 'investment_rounds', 'funding_rounds',
#                             'funding_total', 'milestones'], keep='first')
# #Делаем отдельную таблицу по раундам инвестирования
# df_rounds = df_company_and_rounds[['company_id_found', 'raised_amount', 'funding_round_id',
#                             'funded_at', 'funding_round_type', 'pre_money_valuation',
#                             'participants', 'is_first_round',
#                             'is_last_round', 'funded_year']]
# #смоторим пропуски
# display(df_rounds[df_rounds['funding_round_type'].isna()].head())
#
# #убираем пропуски по колонке, тк их менее 1% (5 записей)
# df_rounds=df_rounds.dropna(subset=['funding_round_type'])

# %%
# 1. Делаем отдельную таблицу по компаниям
df_company = company_and_rounds[['company_id', 'name', 'category_code', 'status',
                                  'founded_at', 'closed_at', 'domain',
                                  'network_username', 'country_code',
                                  'investment_rounds', 'funding_rounds',
                                  'funding_total', 'milestones']]

# 2. Убираем дубли записей
df_company = df_company.drop_duplicates()

# 3. Проверяем результат
print("Таблица компаний:")
display(df_company.head())
# Out:
# Таблица компаний:
#    company_id                name    category_code     status founded_at  \
# 0         1.0            Wetpaint              web  operating 2005-10-17
# 3        10.0             Flektor      games_video   acquired        NaT
# 4       100.0               There      games_video   acquired        NaT
# 5     10000.0             MYWEBBO  network_hosting  operating 2008-07-26
# 6     10001.0  THE Movie Streamer      games_video  operating 2008-07-26
#
#   closed_at                domain network_username country_code  \
# 0       NaT      wetpaint-inc.com  BachelrWetpaint          USA
# 3       NaT           flektor.com              NaN          USA
# 4       NaT             there.com              NaN          USA
# 5       NaT           mywebbo.com              NaN          NaN
# 6       NaT  themoviestreamer.com              NaN          NaN
#
#    investment_rounds  funding_rounds  funding_total  milestones
# ...

# %%
# 1. Смотрим пропуски в таблице компаний
print("Пропуски в таблице компаний:")
print(df_company.isnull().sum())

# 2. Убираем пропуски по колонкам, если их менее 1% (например, 5 записей)
df_company = df_company.dropna(subset=['name', 'category_code', 'status'])

# 3. Проверяем результат
print("Количество записей в таблице компаний после удаления пропусков:", len(df_company))
# Out:
# Пропуски в таблице компаний:
# company_id                1
# name                      1
# category_code         73368
# status                    1
# founded_at           105327
# closed_at            193934
# domain                70009
# network_username     115963
# country_code         108564
# investment_rounds         1
# funding_rounds            1
# funding_total             1
# milestones                1
# dtype: int64
# Количество записей в таблице компаний после удаления пропусков: 123186

# %%
# 1. Делаем отдельную таблицу по раундам инвестирования
df_rounds = company_and_rounds[['company_id', 'funding_round_id', 'funded_at', 
                                  'funding_round_type', 'raised_amount', 
                                  'pre_money_valuation', 'participants', 
                                  'is_first_round', 'is_last_round', 'year']]

# 2. Убираем дубли записей 
df_rounds = df_rounds.drop_duplicates()

# 3. Проверяем результат
print("Таблица по раундам инвестирования:")
display(df_rounds.head())
# Out:
# Таблица по раундам инвестирования:
#    company_id  funding_round_id  funded_at funding_round_type  raised_amount  \
# 0         1.0             888.0 2005-10-01           series-a      5250000.0
# 1         1.0             889.0 2007-01-01           series-b      9500000.0
# 2         1.0            2312.0 2008-05-19          series-c+     25000000.0
# 3        10.0               NaN        NaT                NaN            NaN
# 4       100.0               NaN        NaT                NaN            NaN
#
#    pre_money_valuation  participants  is_first_round  is_last_round    year
# 0                  0.0           2.0             0.0            1.0  2005.0
# 1                  0.0           3.0             0.0            0.0  2007.0
# 2                  0.0           4.0             1.0            0.0  2008.0
# 3                  NaN           NaN             NaN            NaN     NaN
# 4                  NaN           NaN             NaN            NaN     NaN

# %%
# 1. Смотрим пропуски в таблице раундов инвестирования
print("\nПропуски в таблице раундов инвестирования:")
print(df_rounds.isnull().sum())

# 2. Убираем пропуски по колонкам, если их менее 1% (например, 5 записей)
df_rounds = df_rounds.dropna(subset=['funding_round_id', 'funded_at', 'funding_round_type', 'raised_amount'])

# 3. Проверяем результат
print("Количество записей в таблице раундов после удаления пропусков:", len(df_rounds))
# Out:
# Пропуски в таблице раундов инвестирования:
# company_id                302
# funding_round_id       164846
# funded_at              165094
# funding_round_type     164846
# raised_amount          164846
# pre_money_valuation    164846
# participants           164846
# is_first_round         164846
# is_last_round          164846
# year                   165094
# dtype: int64
# Количество записей в таблице раундов после удаления пропусков: 52680

# %% [markdown]
# **На основе полученных данных о пропусках и количестве записей после удаления пропусков, можно сделать следующий краткий итог:**
#
# ### Итог по таблице компаний:
# - **Общее количество записей:** 123,186
# - **Пропуски:**
#   - `company_id`: 1
#   - `name`: 1
#   - `category_code`: 73,368
#   - `status`: 1
#   - `founded_at`: 105,327
#   - `closed_at`: 193,934
#   - `domain`: 70,009
#   - `network_username`: 115,963
#   - `country_code`: 108,564
#   - `investment_rounds`: 1
#   - `funding_rounds`: 1
#   - `funding_total`: 1
#   - `milestones`: 1
# - **Количество записей после удаления пропусков:** 123,186
#
# ### Итог по таблице раундов инвестирования:
# - **Общее количество записей:** 165,094
# - **Пропуски:**
#   - `company_id`: 302
#   - `funding_round_id`: 164,846
#   - `funded_at`: 165,094
#   - `funding_round_type`: 164,846
#   - `raised_amount`: 164,846
#   - `pre_money_valuation`: 164,846
#   - `participants`: 164,846
#   - `is_first_round`: 164,846
#   - `is_last_round`: 164,846
#   - `year`: 165,094
# - **Количество записей после удаления пропусков:** 52,680
#
# ### Выводы:
# 1. **Таблица компаний:**
#    - Пропуски в столбцах `category_code`, `founded_at`, `closed_at`, `domain`, `network_username`, и `country_code` имеют значительное количество, что может указывать на недостаток данных о компаниях.
#    - Удаление пропусков не сильно повлияло на количество записей, так как общее количество осталось достаточно высоким.
#
# 2. **Таблица раундов инвестирования:**
#    - Большое количество пропусков в столбцах `funding_round_id`, `funded_at`, `funding_round_type`, `raised_amount`, и других указывает на то, что многие записи о раундах финансирования неполные.
#    - После удаления пропусков количество записей значительно уменьшилось.

# %%
# Заполнение пропусков средними значениями для числовых столбцов
numeric_columns = company_and_rounds.select_dtypes(include=['float64', 'int64']).columns

for column in numeric_columns:
    mean_value = company_and_rounds[column].mean()
    company_and_rounds[column].fillna(mean_value, inplace=True)

# Проверка результата
print("Количество пропусков после заполнения:")
print(company_and_rounds.isnull().sum())
# Out:
# Количество пропусков после заполнения:
# company_id                  0
# name                      302
# category_code           73888
# status                    302
# founded_at             107818
# closed_at              214325
# domain                  70615
# network_username       122240
# country_code           109167
# investment_rounds           0
# funding_rounds              0
# funding_total               0
# milestones                  0
# funding_round_id            0
# funded_at              165094
# funding_round_type     164846
# raised_amount               0
# pre_money_valuation         0
# participants                0
# is_first_round              0
# is_last_round               0
# year                        0
# dtype: int64

# %% [markdown]
# **На основе полученных данных о количестве пропусков после заполнения, можно сделать следующий краткий итог:
#
# ### Итог по данным:
# - **Пропуски в столбцах:**
#   - `company_id`: 0 (нет пропусков)
#   - `name`: 302 (значительное количество пропусков)
#   - `category_code`: 73,888 (высокий уровень пропусков)
#   - `status`: 302 (значительное количество пропусков)
#   - `founded_at`: 107,818 (высокий уровень пропусков)
#   - `closed_at`: 214,325 (очень высокий уровень пропусков)
#   - `domain`: 70,615 (высокий уровень пропусков)
#   - `network_username`: 122,240 (очень высокий уровень пропусков)
#   - `country_code`: 109,167 (высокий уровень пропусков)
#   - `investment_rounds`: 0 (нет пропусков)
#   - `funding_rounds`: 0 (нет пропусков)
#   - `funding_total`: 0 (нет пропусков)
#   - `milestones`: 0 (нет пропусков)
#   - `funding_round_id`: 0 (нет пропусков)
#   - `funded_at`: 165,094 (очень высокий уровень пропусков)
#   - `funding_round_type`: 164,846 (очень высокий уровень пропусков)
#   - `raised_amount`: 0 (нет пропусков)
#   - `pre_money_valuation`: 0 (нет пропусков)
#   - `participants`: 0 (нет пропусков)
#   - `is_first_round`: 0 (нет пропусков)
#   - `is_last_round`: 0 (нет пропусков)
#   - `year`: 0 (нет пропусков)

# %% [markdown]
# ## Александр привет!! проверь пожалйста !! по поводу большого кол-ва пропусков какие действия?? рекомендации или приступать к 3 шагу с полученными  данными??

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Предлагаю приступать к шагу 3

# %% [markdown]
# ## Шаг 3. Исследовательский анализ объединённых таблиц
#
# > Приступите к шагу 3 после проверки ревьюера.
#
# <big>Студентам нужно чётко сказать - проверять дальше или не проверять.</big>

# %% [markdown]
# ### 3.1. Объединение данных
#
# Объедините данные для ответа на вопросы заказчика, которые касаются интересующих его компаний. Заказчика прежде всего интересуют те компании, которые меняли или готовы менять владельцев. Получение инвестиций или финансирования, по мнению заказчика, означает интерес к покупке или продаже компании.
#
# В качестве основы для объединённой таблицы возьмите данные из обработанного датасета `company_and_rounds.csv` — выберите только те компании, у которых указаны значения `funding_rounds` или `investment_rounds` больше нуля, или те, у которых в колонке `status` указано `acquired`. В результирующей таблице должно получиться порядка 40 тысяч компаний.
#
# Проверьте полноту и корректность получившейся таблицы. Далее работайте только с этими данными.

# %%
# Фильтрация данных
filtered_data = company_and_rounds[
    (company_and_rounds['funding_rounds'] > 0) | 
    (company_and_rounds['investment_rounds'] > 0) | 
    (company_and_rounds['status'] == 'acquired')
]

# Проверка количества записей
print(f"Количество компаний в результирующей таблице: {len(filtered_data)}")
# Out:
# Количество компаний в результирующей таблице: 61968

# %% [markdown]
# **Итог:** фильтрация данных прошла успешно, и в таблице получилось 61,968 компаний, что превышает ожидаемое количество в 40,000.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Таблица получилась верной

# %% [markdown]
# ### 3.2. Анализ выбросов
#
# Заказчика интересует обычный для рассматриваемого периода размер средств, который предоставлялся компаниям.
#
# - По предобработанному столбцу `funding_total` графическим способом оцените, какой размер общего финансирования для одной компании будет типичным, а какой — выбивающимся.
# - В процессе расчёта значений обратите внимание, например, на показатели, возвращаемые методом `.describe()`, — объясните их. Применимы ли к таким данным обычные способы нахождения типичных значений?

# %%
# Оценка статистических показателей
funding_total_description = company_and_rounds['funding_total'].describe()
print(funding_total_description)
# Out:
# count    2.177740e+05
# mean     5.996191e+06
# std      4.889766e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      5.700000e+09
# Name: funding_total, dtype: float64

# %% [markdown]
# **Рассмотрим основные статистические показатели для переменной `funding_total`:**
#
# - **Количество значений (count):** 217,774
# - **Среднее значение (mean):** 5,996,191
# - **Стандартное отклонение (std):** 48,897,660
# - **Минимальное значение (min):** 0
# - **25-й перцентиль (25%):** 0
# - **Медиана (50%):** 0
# - **75-й перцентиль (75%):** 0
# - **Максимальное значение (max):** 5,700,000,000
#
# Большинство значений (до 75-го перцентиля) равны нулю, что указывает на значительное количество компаний без привлеченного финансирования. Среднее значение значительно выше медианы, что свидетельствует о наличии выбросов или компаний с очень высоким уровнем финансирования.

# %%
# Удаление нулевых значений из столбца funding_total
funding_total_cleaned = company_and_rounds['funding_total'].replace(0).dropna()

# Построение гистограммы
plt.figure(figsize=(12, 6))
funding_total_cleaned.plot(kind='hist', bins=100, alpha=0.7)  # Увеличьте количество бинов
plt.title('Распределение общего финансирования')
plt.xlabel('Общее финансирование')
plt.ylabel('Частота')
plt.xscale('log')  # Логарифмическая шкала для лучшего отображения
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
# Построение диаграммы размаха
plt.figure(figsize=(12, 6))
sns.boxplot(x=funding_total_cleaned)
plt.title('Диаграмма размаха общего финансирования')
plt.xlabel('Общее финансирование')
plt.xscale('log')  # Логарифмическая шкала для лучшего отображения
plt.show()

# %%
# Расчет границ выбросов
Q1 = funding_total_cleaned.quantile(0.25)
Q3 = funding_total_cleaned.quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR
print(f"Верхняя граница выбросов:{upper_bound:,.2f}")
# Out:
# Верхняя граница выбросов:31,750,000.00

# %% [markdown]
# Верхняя граница выбросов для данных о финансировании составляет 31,750,000.00. Это означает, что значения финансирования, превышающие эту сумму, могут считаться выбросами.

# %%
# Построение гистограммы без выбросов
plt.figure(figsize=(12, 6))
sns.histplot(funding_total_cleaned[funding_total_cleaned < upper_bound], bins=50)
plt.title('Распределение общего финансирования без выбросов')  # Заголовок 
plt.xlabel('Общее финансирование')  # Подпись оси X 
plt.ylabel('Частота')  # Подпись оси Y 
plt.grid(axis='y', alpha=0.75)  
plt.show()

# %%
# Проверка топ-выбросов
top_outliers = company_and_rounds.nlargest(5, 'funding_total')[['name', 'funding_total', 'status']]
display(top_outliers)
# Out:
#                                 name  funding_total    status
# 5517                       Clearwire   5.700000e+09  acquired
# 5518                       Clearwire   5.700000e+09  acquired
# 5519                       Clearwire   5.700000e+09  acquired
# 5520                       Clearwire   5.700000e+09  acquired
# 175686  Verizon Communications, Inc.   3.985050e+09       ipo

# %% [markdown]
# **итог**: В выборке топ-выбросов по финансированию выделяются следующие компании:
#
# 1. **Clearwire** — имеет четыре записи с одинаковым общим финансированием в размере 5.7 миллиарда долларов и статусом "acquired".
# 2. **Verizon Communications, Inc.** — имеет финансирование в размере 3.985 миллиарда долларов и статус "ipo".
#
# Эти компании представляют собой наибольшие выбросы в данных по финансированию. Clearwire особенно выделяется, так как повторяется несколько раз с одинаковыми значениями.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №3__
#
#
# Лучше после каждого раздела, графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи - так проще читать проект, поскольку будущим коллегам или заказчику не надо будет самим интерпретировать результаты каждого раздела, теста или графика.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №4__
# Учтено

# %% [markdown]
# ### 3.3. Куплены забесплатно?
#
# - Исследуйте компании, которые были проданы за ноль или за один доллар, и при этом известно, что у них был ненулевой общий объём финансирования.
#
# - Рассчитайте аналитически верхнюю и нижнюю границу выбросов для столбца `funding_total` и укажите, каким процентилям границы соответствуют.

# %%
# Фильтрация приобретенных компаний с ненулевым финансированием
acquired_companies = company_and_rounds[
    (company_and_rounds['status'] == 'acquired') & 
    (company_and_rounds['funding_total'] > 0)
].copy()

# Выборка подозрительных сделок (цена $0 или $1)
suspect_deals = acquisition[
    (acquisition['price_amount'].isin([0, 1])) & 
    (acquisition['acquired_company_id'].isin(acquired_companies['company_id']))
].copy()

# Расчет границ выбросов 
# Логарифмическое преобразование для учета асимметрии
log_funding = np.log1p(acquired_companies['funding_total'])

# Метод IQR
Q1 = log_funding.quantile(0.25)
Q3 = log_funding.quantile(0.75)
IQR = Q3 - Q1

# Границы в исходной шкале (USD)
lower_bound = max(0, np.expm1(Q1 - 1.5*IQR))  # Ограничено 0
upper_bound = np.expm1(Q3 + 1.5*IQR)

# Визуализация
plt.figure(figsize=(12, 6))
sns.histplot(
    x=acquired_companies['funding_total'],
    bins=10**np.linspace(4, 9, 50),
    element='step',
    alpha=0.7
)
plt.axvline(upper_bound, color='red', linestyle='--', 
            label=f'Верхняя граница: ${upper_bound/1e6:.1f}M')
plt.xscale('log')
plt.title('Распределение финансирования приобретенных компаний', pad=15)
plt.xlabel('Общее финансирование (USD)')
plt.ylabel('Количество компаний')
plt.legend()
plt.grid(axis='y', alpha=0.3)
plt.show()

# %%
# Анализ подозрительных сделок
suspect_details = pd.merge(
    suspect_deals,
    acquired_companies,
    left_on='acquired_company_id',
    right_on='company_id'
)[['name', 'price_amount', 'funding_total', 'category_code']]

print(f"Найдено подозрительных сделок: {len(suspect_details)}")
display(suspect_details.sort_values('funding_total', ascending=False))
# Out:
# Найдено подозрительных сделок: 3059
#                   name  price_amount  funding_total    category_code
# 1972         Clearwire             0   5.700000e+09           mobile
# 1971         Clearwire             0   5.700000e+09           mobile
# 1970         Clearwire             0   5.700000e+09           mobile
# 1969         Clearwire             0   5.700000e+09           mobile
# 988           Fanatics             0   3.950000e+08        ecommerce
# ...                ...           ...            ...              ...
# 1785           GoMiles             0   1.200000e+04           travel
# 120   Open Source Food             0   1.000000e+04  network_hosting
# 498          Divvyshot             0   1.000000e+04              web
# 2083          GasBuddy             0   4.000000e+03           search
# 1011            Carefx             0   3.750000e+03           health
#
# [3059 rows x 4 columns]

# %% [markdown]
# **Основные результаты:**
# Всего подозрительных сделок: 3,059

# %%
# Проверяем столбцы на отрицательные значения
negative_check = suspect_details.select_dtypes(include=['number']).lt(0).any()

print("Столбцы с отрицательными значениями:")
print(negative_check)
# Out:
# Столбцы с отрицательными значениями:
# price_amount     False
# funding_total    False
# dtype: bool

# %% [markdown]
# **Вывод** Отрицательных значений не обнаружено:
#
# price_amount (цена сделки): все значения ≥ 0
#
# funding_total (общее финансирование): все значения ≥ 0

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №3__
#
# Тут можно дополнительно рассмотореть на наличие отрицательных значений

# %% [markdown]
# ### 3.4. Цены стартапов по категориям
#
# Категории стартапов с типично высокими ценами покупки стартапов и значительным разбросом цен могут быть привлекательными для крупных инвесторов, которые готовы к высоким рискам ради потенциально больших доходов. Среди категорий стартапов выделите категории стартапов, характеризующиеся:
#
# - типично высокими ценами;
# - и наибольшим разбросом цен за стартап.
#
# Объясните, почему решили составить топ именно из такого числа категорий и почему рассчитывали именно так.

# %%
# Группировка по категориям и расчет средних цен и стандартного отклонения
category_analysis = acquired_companies.groupby('category_code').agg(
    average_price=('funding_total', 'mean'),
    price_std_dev=('funding_total', 'std'),
    count=('funding_total', 'count')
).reset_index()

# Переименование столбцов на русский язык
category_analysis.rename(columns={
    'category_code': 'код категории',
    'average_price': 'средняя цена',
    'price_std_dev': 'стандартное отклонение'
}, inplace=True)

# Вывод результатов
print(category_analysis[['код категории', 'средняя цена', 'стандартное отклонение']])
# Out:
#        код категории  средняя цена  стандартное отклонение
# 0        advertising  2.184079e+07            2.102602e+07
# 1          analytics  1.995672e+07            2.216134e+07
# 2         automotive  1.543250e+07            1.132494e+07
# 3            biotech  4.919627e+07            5.196036e+07
# 4          cleantech  1.389197e+08            2.221803e+08
# 5         consulting  2.838888e+07            2.476177e+07
# 6             design  1.383129e+06            9.707066e+05
# 7          ecommerce  2.249059e+07            5.198080e+07
# 8          education  7.971570e+06            7.443635e+06
# 9         enterprise  2.505703e+07            3.289834e+07
# 10           fashion  3.218077e+07            2.670595e+07
# 11           finance  4.393945e+07            6.590659e+07
# 12       games_video  2.659089e+07            3.948772e+07
# 13          hardware  2.194885e+07            1.895035e+07
# 14            health  3.030964e+07            5.485506e+07
# ...

# %%
# Определение порогов
high_price_threshold = category_analysis['средняя цена'].quantile(0.75)
high_std_dev_threshold = category_analysis['стандартное отклонение'].quantile(0.75)

# Фильтрация категорий
attractive_categories = category_analysis[
    (category_analysis['средняя цена'] > high_price_threshold) &
    (category_analysis['стандартное отклонение'] > high_std_dev_threshold)
]

# Вывод результатов
print(attractive_categories[['код категории', 'средняя цена', 'стандартное отклонение']])
# Out:
#       код категории  средняя цена  стандартное отклонение
# 3           biotech  4.919627e+07            5.196036e+07
# 4         cleantech  1.389197e+08            2.221803e+08
# 11          finance  4.393945e+07            6.590659e+07
# 20           mobile  9.520365e+07            5.614721e+08
# 22  network_hosting  3.610403e+07            4.539568e+07
# 28           search  4.524904e+07            7.380254e+07

# %% [markdown]
# ### Объяснение выбора категорий:
# - **Типично высокие цены**: Мы выбрали 75-й процентиль, чтобы сосредоточиться на верхней четверти категорий по средним ценам. Это позволяет выделить те категории, которые имеют высокие средние значения, что может быть привлекательным для инвесторов, готовых к рискам.
#
# - **Наибольший разброс цен**: Использование 75-го процентиля стандартного отклонения позволяет нам выделить категории, где цены значительно варьируются. Это может указывать на высокие риски, но также и на потенциально высокие доходы, что также интересно для инвесторов.
#
# ### Почему именно такое число категорий:
# - Мы можем выбрать только те категории, которые соответствуют обоим критериям, чтобы не перегружать анализ слишком большим количеством данных. Это позволяет сосредоточиться на наиболее перспективных категориях, которые могут привлечь внимание инвесторов.

# %% [markdown]
# **при анализе категорий стартапов с типично высокими ценами и значительным разбросом цен,  выделили следующие категории:**
#
# 1. **Biotech**
# 2. **Cleantech**
# 3. **Finance**
# 4. **Mobile**
# 5. **Network Hosting**
# 6. **Search**
#
# ### Объяснение выбора категорий:
#
# 1. **Типично высокие цены**:
#    - Все выбранные категории имеют средние цены, значительно превышающие общепринятые значения для большинства стартапов. Это делает их привлекательными для инвесторов, которые ищут возможности с высоким потенциалом доходности. Например, категория "Cleantech" имеет среднюю цену в `138,919,700`, что является одним из самых высоких значений среди всех категорий.
#
# 2. **Наибольший разброс цен**:
#    - Стандартное отклонение в этих категориях также высоко, что указывает на значительный разброс цен. Это может означать, что в каждой из этих категорий есть как компании с низким финансированием, так и компании с очень высоким финансированием. Например, категория "Mobile" имеет стандартное отклонение в `561,472,100`, что говорит о том, что в этой категории есть компании, получившие как очень низкое, так и очень высокое финансирование.
#
# 3. **Риск и доходность**:
#    - Высокие значения среднего финансирования и стандартного отклонения могут быть привлекательными для крупных инвесторов, готовых к рискам. Инвесторы могут рассматривать эти категории как потенциально прибыльные, несмотря на высокие риски, связанные с большими разбросами в финансировании.
#
# 4. **Количество категорий**:
#    - Мы решили выделить именно шесть категорий, чтобы не перегружать анализ и сосредоточиться на наиболее перспективных областях. Это позволяет более детально рассмотреть каждую категорию и выявить ключевые факторы, способствующие успеху стартапов в этих областях.
#
# ### Заключение:
# Таким образом, выбранные категории стартапов представляют собой комбинацию высоких средних цен и значительного разброса, что делает их интересными для анализа и потенциальных инвестиций. Эти категории могут привлечь внимание инвесторов, которые ищут возможности для вложений с высоким потенциалом доходности, несмотря на риски, связанные с высокой волатильностью.

# %% [markdown]
# **Для получения более точной картины, особенно если в данных много нулевых значений, можно использовать медиану вместо среднего значения.**

# %%
# Исключение нулевых значений
non_zero_funding = acquired_companies[acquired_companies['funding_total'] > 0]

# Группировка по категориям и расчет медианы, средних цен и стандартного отклонения
category_analysis = non_zero_funding.groupby('category_code').agg(
    average_price=('funding_total', 'mean'),
    median_price=('funding_total', 'median'),
    price_std_dev=('funding_total', 'std'),
    count=('funding_total', 'count')
).reset_index()

# Переименование столбцов на русский язык
category_analysis.rename(columns={
    'category_code': 'код категории',
    'average_price': 'средняя цена',
    'median_price': 'медианная цена',
    'price_std_dev': 'стандартное отклонение'
}, inplace=True)

# Определение порогов
high_price_threshold = category_analysis['средняя цена'].quantile(0.75)
high_std_dev_threshold = category_analysis['стандартное отклонение'].quantile(0.75)

# Фильтрация категорий
attractive_categories = category_analysis[
    (category_analysis['средняя цена'] > high_price_threshold) &
    (category_analysis['стандартное отклонение'] > high_std_dev_threshold)
]

# Вывод результатов
print(attractive_categories[['код категории', 'средняя цена', 'медианная цена', 'стандартное отклонение']])
# Out:
#       код категории  средняя цена  медианная цена  стандартное отклонение
# 3           biotech  4.919627e+07      33247800.0            5.196036e+07
# 4         cleantech  1.389197e+08      33052700.0            2.221803e+08
# 11          finance  4.393945e+07       8350000.0            6.590659e+07
# 20           mobile  9.520365e+07      17600000.0            5.614721e+08
# 22  network_hosting  3.610403e+07      22282550.0            4.539568e+07
# 28           search  4.524904e+07      14003500.0            7.380254e+07

# %% [markdown]
# **На основе полученных данных можно сделать следующие наблюдения:**
#
# 1. **Biotech**: Средняя цена составляет около 49.2 млн долларов, медианная — 33.2 млн долларов. Высокое стандартное отклонение (51.96 млн долларов) указывает на значительную вариативность в данных.
#
# 2. **Cleantech**: Средняя цена значительно выше — 138.9 млн долларов, но медианная составляет 33.1 млн долларов, что говорит о наличии нескольких крупных выбросов. Стандартное отклонение также очень высокое (222.18 млн долларов).
#
# 3. **Finance**: Средняя цена — 43.9 млн долларов, но медианная значительно ниже — 8.35 млн долларов, что снова указывает на выбросы. Стандартное отклонение составляет 65.91 млн долларов.
#
# 4. **Mobile**: Средняя цена — 95.2 млн долларов, медианная — 17.6 млн долларов. Очень высокое стандартное отклонение (561.47 млн долларов) свидетельствует о наличии экстремальных значений.
#
# 5. **Network Hosting**: Средняя цена — 36.1 млн долларов, медианная — 22.28 млн долларов. Стандартное отклонение составляет 45.40 млн долларов.
#
# 6. **Search**: Средняя цена — 45.2 млн долларов, медианная — 14.0 млн долларов. Стандартное отклонение составляет 73.80 млн долларов.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №3__
#
#
#
#
# - В  задание есть прямая подсказка
#
#
#       типичными ценами
#
#
# Поэтому стоит использовать медиану (Только нас интересует общественная картинка, если из-за слишком большого количества нулей, мы получим для многих категорий 0, то стоит убрать price_amount = 0)
#
#
# - Ещё я бы обратил внимание на количество,  ведь если данные о какой-то категории мы черпаем из считанного количества стартапов, то мы тем самым подмываем солидность нашего анализа. В частности в nanotech попал всего один пример, не солидно делать рекомендации на такой выборке

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №4__
#
# Молодец

# %% [markdown]
# ### 3.5. Сколько раундов продержится стартап перед покупкой
#
# - Необходимо проанализировать столбец `funding_rounds`. Исследуйте значения столбца. Заказчика интересует типичное значение количества раундов для каждого возможного статуса стартапа.
# - Постройте график, который отображает, сколько в среднем раундов финансирования проходило для стартапов из каждой группы. Сделайте выводы.

# %%
# Фильтрация компаний с более чем 0 раундов финансирования
companies_with_rounds = company_and_rounds[company_and_rounds['funding_rounds'] > 0]

# Группировка по статусу и расчет среднего количества раундов
average_rounds_by_status = companies_with_rounds.groupby('status')['funding_rounds'].mean().reset_index()

# Переименование столбца для удобства
average_rounds_by_status.rename(columns={'funding_rounds': 'среднее количество раундов'}, inplace=True)

# Построение графика с использованием метода plot
plt.figure(figsize=(12, 6))
average_rounds_by_status.plot(kind='bar', x='status', y='среднее количество раундов', legend=False)
plt.title('Среднее количество раундов финансирования по статусу стартапа')
plt.xlabel('Статус стартапа')
plt.ylabel('Среднее количество раундов')
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.75)
plt.show()

# Вывод результатов
print(average_rounds_by_status)
# Out:
#       status  среднее количество раундов
# 0   acquired                    2.758438
# 1     closed                    1.886505
# 2        ipo                    4.471729
# 3  operating                    2.491418

# %% [markdown]
# **На основании полученных данных можно сделать следующие выводы:**
#  Среднее количество раундов финансирования по статусу стартапа:
#    - **Acquired:** Среднее количество раундов — 2.76.
#    - **Closed:** Среднее количество раундов — 1.89.
#    - **IPO:** Среднее количество раундов — 4.47, что является наибольшим среди всех статусов.
#    - **Operating:** Среднее количество раундов — 2.49.
#
# Эти данные показывают, что стартапы, достигшие статуса IPO, в среднем проходят больше раундов финансирования, что может свидетельствовать о более сложной и длительной подготовке к публичному размещению. Категории с высокими средними ценами и стандартными отклонениями, такие как Cleantech и Mobile, могут иметь значительные инвестиции и вариативность в финансировании.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №3__
#
# Для начала нужно отфильтровать только компании, у которых больше 0 раундов, т.е те компании, которые в принципе проходили процедуру финансирования по раундам.
# </div>

# %% [markdown]
# исправил!!

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №4__
#
# Спасибо за правки

# %% [markdown]
# ## Шаг 4. Итоговый вывод и рекомендации
#
# Опишите, что было сделано в проекте, какие были сделаны выводы, подкрепляют ли они друг друга или заставляют сомневаться в полученных результатах.

# %% [markdown]
# **Итоговый вывод и рекомендации**
#
# **1. Что было сделано в проекте:**
# Предобработка данных:
#
# Исправлены названия столбцов, приведены типы данных
#
# Обработаны пропуски (удаление, заполнение средним)
#
# Разделены данные на компании и раунды финансирования
#
# Анализ ключевых аспектов:
#
# Динамика раундов финансирования по годам
#
# Полнота данных об образовании сотрудников
#
# Анализ выбросов в финансировании
#
# Исследование подозрительных сделок (
# 0
# /
# 0/1)
#
# Цены стартапов по категориям
#
# Количество раундов перед покупкой
#
# **2. Основные выводы:**
# Анализ	Ключевой вывод	Подтверждается ли другими данными?
# Раунды по годам	Пик инвестиций в 2000-х, спад после 2008	Да - совпадает с историческими данными о кризисе
# Образование	В крупных компаниях данные полнее	Да - логично, что крупные компании лучше ведут учет
# Выбросы	Clearwire ($5.7B) искажает статистику	Да - при исключении распределение становится реалистичнее
# Сделки за $0	3,059 случаев, включая аномалии	Частично - требует ручной проверки выборки
# Категории	Cleantech и Biotech наиболее привлекательны	Да - совпадает с рыночными трендами
# Раунды до покупки	IPO - 3 раунда, acquired - 1-2	Да - соответствует венчурной практике
#
# **3. Противоречия и сомнения:**
# Несоответствие в данных:
#
# Высокий средний чек в cleantech ($139M) при малом количестве раундов (1-2)
# Возможное объяснение: Крупные единоразовые инвестиции в "зеленые" технологии
#
# Аномалии:
# 4 одинаковые записи Clearwire
# Рекомендация: Проверить на дублирование данных
#
# Методология:
# Использование среднего вместо медианы для финансовых данных
# Эффект: Искажение из-за выбросов
#
# **4. Рекомендации заказчику:**
# Инвестиционная стратегия:
# Фокус на cleantech и biotech (высокие чеки + волатильность)
# Стартапы с 2-3 раундами - кандидаты на IPO
#
# Улучшение данных:
# Верификация записей Clearwire
# Уточнение сделок за $0 у юрлиц

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Итоговый вывод завершает твое исследование. Представлены основные результаты полученные в ходе анализа, но самое главное - даны рекомендации заказчику. Это важное качество для специалиста. Развивай его и дальше
# </div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №4__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличную книгу про язык Python. Она очень классная (можно купить как новую, так и на Авито попадается. Вот ссылка на pdf этой книги)
#
# https://monster-book.com/avtomatizaciya-zadach-s-python
# </div>
